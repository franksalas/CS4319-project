# %% [markdown]
# ## Salary data for UH System

# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
uh_salary_df = pd.read_csv('uhsal.csv')

# %%
uh_salary_df.head()
# Out:
#                      Name                        JobTitle Campus  \
# 0       Vitek,Mark Gerard  Asst Dir, RLH Conduct/Assessmt  HR730
# 1  Haynes,Eleanor Beavers                 Adjunct Faculty  HR730
# 2            Greer,Tomika    Visiting Assistant Professor  HR730
# 3           Yuan,Xiaojing             Associate Professor  HR730
# 4            Quintero,Sam     Adjunct Associate Professor  HR730
#
#                        DeptName Sex EthnicGrp HireDate   FullPart  AnnualSal
# 0    Student Housing & Res Life   M     WHITE  3/23/09  Full-Time   69700.08
# 1                     Dean, Law   F     BLACK   9/1/10  Part-Time    4400.01
# 2  Human Develop & Consumer Sci   F     BLACK   9/1/10  Full-Time   61950.00
# 3         Electrical Technology   F     ASIAN   8/1/04  Full-Time   93764.97
# 4               Dean, Optometry   M     HISPA   9/1/72  Full-Time   95900.04

# %%
uh_salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14085 entries, 0 to 14084
# Data columns (total 9 columns):
# Name         14085 non-null object
# JobTitle     14085 non-null object
# Campus       14085 non-null object
# DeptName     14085 non-null object
# Sex          14085 non-null object
# EthnicGrp    14066 non-null object
# HireDate     14085 non-null object
# FullPart     14085 non-null object
# AnnualSal    14085 non-null float64
# dtypes: float64(1), object(8)
# memory usage: 1.1+ MB

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
uh_salary_df
# Out:
#                                   Name                        JobTitle Campus  \
# 0                    Vitek,Mark Gerard  Asst Dir, RLH Conduct/Assessmt  HR730
# 1               Haynes,Eleanor Beavers                 Adjunct Faculty  HR730
# 2                         Greer,Tomika    Visiting Assistant Professor  HR730
# 3                        Yuan,Xiaojing             Associate Professor  HR730
# 4                         Quintero,Sam     Adjunct Associate Professor  HR730
# 5                Ibidapo-Obe,Seunfunmi           Student Worker (NCWS)  HR730
# 6                          Ma,Xiaoshan           Student Worker (NCWS)  HR730
# 7                         Liu,Tingting              Teaching Assistant  HR730
# 8                    Vallejo,Anthony R                     Spvr, Lab 1  HR730
# 9                       Cassler,Daniel   Associate Professor, Instruct  HR730
# 10                   Crocker,Charles A            Dir, Career Services  HR759
# 11                    Angamarca,Nora A                     Custodian 1  HR730
# 12                   Lytwyn,Jennifer N   Assistant Professor, Instruct  HR730
# 13                   Miljanic,Ognjen S             Associate Professor  HR730
# 14                        Lopez,John C              Clinical Asst Prof  HR730
# 15                     Moghaddam,Kaveh                  Asst Professor  HR765
# 16                    Ragazzo,Robert A                       Professor  HR730
# 17                    Mariotto,Marco J                       Professor  HR730
# 18           Alexander,Brandon Micheal          Operations Crew Member  HR730
# 19               Truong,Thuy Vuong Thi            Analyst, Financial 2  HR730
# 20                       Rimer,Jeffrey             Associate Professor  HR730
# 21                  Gustafsson,Jan-Ake                       Professor  HR730
# 22               Ajoku,Oluchi Blessing         Instructional Assistant  HR730
# 23                      Goldfarb,Rysse                 Temporary Staff  HR730
# 24               Cervenka,Mark William             Associate Professor  HR784
# 25                      Vincent,John P                       Professor  HR730
# 26                     Sager,William W                       Professor  HR730
# 27                       Long,Stuart A                       Professor  HR730
# 28                   Chen,Linlin Irene                       Professor  HR784
# 29                      Marquez,Judith                       Professor  HR759
# ...                                ...                             ...    ...
# 20               Chemical Engineering   M     WHITE    9/1/09  Full-Time
# 21     Ctr for Nuclear Rec & Cell Sig   M     WHITE    1/1/09  Part-Time
# 22       Human Develop & Consumer Sci   F     BLACK   4/24/14  Part-Time
# 23            Communication Disorders   F     WHITE   8/20/13  Part-Time
# 24                Arts and Humanities   M     WHITE    9/1/00  Full-Time
# 25                         Psychology   M     WHITE    9/1/72  Part-Time
# 26       Earth & Atmospheric Sciences   M     WHITE    1/1/13  Full-Time
# 27             Electrical Engineering   M     WHITE    9/1/74  Full-Time
# 28                    Urban Education   F     ASIAN   2/12/98  Full-Time
# 29                  SOE Dean's Office   F     HISPA    9/1/89  Full-Time
# ...                               ...  ..       ...       ...        ...
# 14055      University Career Services   F     WHITE    8/1/11  Full-Time
# 14056      Local Maintenance Services   F     HISPA   7/26/11  Full-Time
# 14057                 Faculty Affairs   F     HISPA  10/25/77  Full-Time
# 14058                         English   F     HISPA    9/1/91  Full-Time
# 14059          Accountancy & Taxation   M     WHITE    9/1/80  Full-Time
# 14060            Engineering Services   F     ASIAN   4/16/01  Full-Time
# 14061                  Dean, Pharmacy   M     WHITE    2/6/06  Full-Time
# 14062      Student Housing & Res Life   F     BLACK   5/11/07  Full-Time
# 14063               Aerospace Studies   F     HISPA   6/22/98  Full-Time
# 14064                 Dean, Optometry   F     HISPA   11/2/98  Full-Time
# 14065            Campus Solutions Svc   F     BLACK   5/13/96  Full-Time
# 14066    Earth & Atmospheric Sciences   M     WHITE   9/18/00  Part-Time
# 14067                   Communication   F     HISPA  10/18/04  Full-Time
# 14068        Curriculum & Instruction   M     WHITE    8/9/10  Full-Time
# 14069                Optometry Clinic   F     HISPA   8/16/10  Full-Time
# 14070               Civil Engineering   M     WHITE    9/1/10  Full-Time
# 14071            Chemical Engineering   M     NSPEC    9/1/13  Part-Time
# 14072                      Psychology   F     ASIAN    9/2/08  Full-Time
# 14073                 Dean, Optometry   M     WHITE   10/1/75  Full-Time
# 14074          Mechanical Engineering   M     WHITE   7/15/87  Full-Time
# 14075            University Libraries   F     WHITE   10/6/08  Full-Time
# 14076   Technology Services & Support   M     WHITE   4/18/00  Full-Time
# 14077                         Theatre   M     HISPA   4/16/05  Full-Time
# 14078                           Music   F     WHITE  11/10/08  Full-Time
# 14079   Hotel & Restaurant Management   F     HISPA   5/27/09  Full-Time
# 14080        Business Operations & IT   F     WHITE   3/23/15  Part-Time
# 14081  Criminal Justice Training Ctr.   M     BLACK   6/30/93  Part-Time
# 14082                       Computing   F     ASIAN    9/2/15  Part-Time
# 14083                Computer Science   F     ASIAN    9/1/13  Part-Time
# 14084      Health & Human Performance   F     WHITE    9/1/09  Full-Time
#
#        AnnualSal
# 0       69700.08
# 1        4400.01
# 2       61950.00
# 3       93764.97
# 4       95900.04
# 5       10400.00
# 6       10400.00
# 7       11286.00
# 8       45390.00
# 9       71799.96
# 10      75182.04
# 11      19323.20
# 12      61635.96
# 13     119952.00
# 14      95281.02
# 15      93730.05
# 16     164100.06
# 17     202209.03
# 18      36609.96
# 19      59004.00
# 20     127512.00
# 21     153751.59
# 22       9000.00
# 23      16640.00
# 24      71203.32
# 25      78294.78
# 26     151591.05
# 27     205656.12
# 28      78840.99
# 29      72594.72
# ...          ...
# 14055   41187.00
# 14056   21964.80
# 14057   85100.04
# 14058   73584.96
# 14059  129785.13
# 14060   69180.00
# 14061   66834.00
# 14062   33225.00
# 14063   46633.20
# 14064   41013.00
# 14065  127336.80
# 14066   98416.32
# 14067   28516.80
# 14068   70561.08
# 14069   37468.56
# 14070  102626.01
# 14071   24199.92
# 14072   76515.96
# 14073  122335.11
# 14074  106132.86
# 14075  132992.04
# 14076   71075.64
# 14077   34299.20
# 14078   45884.04
# 14079   19219.20
# 14080   18000.00
# 14081    1820.00
# 14082    8632.00
# 14083   14850.00
# 14084   71499.96
#
# [14085 rows x 9 columns]

# %%
sns.factorplot('Sex',data=uh_salary_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-cd667b5e79aa> in <module>()
# ----> 1 sns.factorplot('Sex',data=uh_salary_df)
#
# //anaconda/lib/python2.7/site-packages/seaborn/categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3365
#    3366     # Draw the plot onto the facets
# -> 3367     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3368
#    3369     # Special case axis labels for a count type plot
#
# //anaconda/lib/python2.7/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     791
#     792             # Draw the plot
# --> 793             self._facet_plot(func, ax, args, kwargs)
#     794
#     795         # Finalize the annotations and layout
#
# //anaconda/lib/python2.7/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     809
#     810         # Draw the plot
# --> 811         func(*plot_args, **plot_kwargs)
#     812
#     813         # Sort out the supporting information
#
# //anaconda/lib/python2.7/site-packages/seaborn/categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, ax, **kwargs)
#    3009                             estimator, ci, n_boot, units,
#    3010                             markers, linestyles, dodge, join, scale,
# -> 3011                             orient, color, palette)
#    3012
#    3013     if ax is None:
#
# //anaconda/lib/python2.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette)
#    1575                                  order, hue_order, units)
#    1576         self.establish_colors(color, palette, 1)
# -> 1577         self.estimate_statistic(estimator, ci, n_boot)
#    1578
#    1579         # Override the default palette for single-color plots
#
# //anaconda/lib/python2.7/site-packages/seaborn/categorical.py in estimate_statistic(self, estimator, ci, n_boot)
#    1434                     statistic.append(np.nan)
#    1435                 else:
# -> 1436                     statistic.append(estimator(stat_data))
#    1437
#    1438                 # Get a confidence interval for this estimate
#
# //anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in mean(a, axis, dtype, out, keepdims)
#    2872
#    2873     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2874                           out=out, keepdims=keepdims)
#    2875
#    2876
#
# //anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      70         ret = ret.dtype.type(ret / rcount)
#      71     else:
# ---> 72         ret = ret / rcount
#      73
#      74     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
sns.factorplot('Sex',data=uh_salary_df, kind="count")

# %%
sns.factorplot('Sex',data=uh_salary_df, kind="count", hue='EthnicGrp')

# %%
sns.factorplot('EthnicGrp',data=uh_salary_df, kind="count", hue='Sex')
